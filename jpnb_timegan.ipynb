# %%
import numpy as np
import matplotlib.pyplot as plt

load = np.load('timegan_results.npz')

load['gen'].shape
load['gen'].reshape(load['gen'].shape[0], load['gen'].shape[1])
# Out:
# array([[0.76720989, 0.71445727, 0.68651682, ..., 0.65691555, 0.65741283,
#         0.65619659],
#        [0.21065977, 0.24443012, 0.22499165, ..., 0.21724242, 0.2195197 ,
#         0.20781538],
#        [0.39387837, 0.41138095, 0.3698256 , ..., 0.25648805, 0.29608431,
#         0.27090028],
#        ...,
#        [0.62583119, 0.63421726, 0.63156873, ..., 0.66403604, 0.65661716,
#         0.66246945],
#        [0.55650496, 0.57803613, 0.57031989, ..., 0.65269172, 0.65345776,
#         0.65622532],
#        [0.42562133, 0.44149262, 0.3990314 , ..., 0.30678466, 0.28430015,
#         0.28179017]])

# %%
plt.plot(load['gen'].reshape(load['gen'].shape[0], load['gen'].shape[1])[:,:].T)
plt.show()
